# %%
import psycopg2 as pg
import pandas.io.sql as psql

# %%
psql.read_sql("SELECT ST_AsText(ST_Centroid(geom)) FROM Bangalore", connection)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# ~/Downloads/ENTER/lib/python3.6/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1403             else:
# -> 1404                 cur.execute(*args)
#    1405             return cur
#
# ProgrammingError: column "wkb_geometry" does not exist
# LINE 1: SELECT ST_AsText(ST_Centroid(wkb_geometry)) FROM Bangalore
#                                      ^
#
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-5-c62b3c8dac08> in <module>()
# ----> 1 psql.read_sql("SELECT ST_AsText(ST_Centroid(wkb_geometry)) FROM Bangalore", connection)
#
# ~/Downloads/ENTER/lib/python3.6/site-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
# ...

# %%
connection = pg.connect("dbname=city user=sandyjones")

dataframe = psql.read_sql("SELECT * FROM Bangalore", connection)

# %%
dataframe
# Out:
#      gid  objectid ass_const_           ass_const1  ward_no  \
# 0      1       1.0        150            Yelahanka      2.0
# 1      2       2.0        150            Yelahanka      3.0
# 2     34      34.0        155          Dasarahalli     39.0
# 3      3       3.0        150            Yelahanka      4.0
# 4      4       4.0        151           K.R. Puram     51.0
# 5     22      22.0        154  Rajarajeswari Nagar     16.0
# 6     23      23.0        154  Rajarajeswari Nagar    160.0
# 7      5       5.0        151           K.R. Puram     53.0
# 8      6       6.0        151           K.R. Puram     54.0
# 9      7       7.0        151           K.R. Puram     55.0
# 10     8       8.0        151           K.R. Puram     56.0
# 11    11      11.0        152      Byatarayanapura     10.0
# 12     9       9.0        151           K.R. Puram     81.0
# 13    10      10.0        151           K.R. Puram     87.0
# 14    48      48.0        157          Malleswaram     64.0
# ...
